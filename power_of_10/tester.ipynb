# %%
from athletes import search_athletes

search_athletes(firstname='dylan',surname='schubert',club='southend')
# Out:
# [{'firstname': 'Dylan',
#   'surname': 'Schubert',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Southend',
#   'athlete_id': '1125172'}]

# %%
from athletes import get_athlete
get_athlete(714350)
# Out:
# {'club': 'Basildon',
#  'gender': 'Female',
#  'age_group': 'SEN',
#  'county': 'Essex',
#  'region': 'East',
#  'nation': 'England',
#  'lead coach': 'Unknown',
#  'about': 'Login to add some details about this athlete',
#  'pb': [{'event': '200', 'value': '30.4'},
#   {'event': '800', 'value': '2:30.39'},
#   {'event': '1500', 'value': '5:05.34'},
#   {'event': 'parkrun', 'value': '19:47'}],
#  'performances': [{'event': '5KMT',
#    'value': '20:08',
#    'position': ['7', ''],
#    'venue': 'Basildon',
#    'meeting': 'Crown to Crown Good Friday 5K',
#    'date': '15 Apr 22'},
#   {'event': 'parkrun',
#    'value': '19:47',
#    'position': ['9', ''],
#    'venue': 'Chalkwell Beach',
#    'meeting': 'Chalkwell Beach parkrun # 37',
#    'date': '19 Mar 22'},
#   {'event': 'ZXC',
#    'value': 'NT',
#    'position': ['5', ''],
#    'venue': 'Hockley',
#    'meeting': 'Essex League',
#    'date': '25 Sep 21'},
#   {'event': '6KXC',
#    'value': '26:55',
#    'position': ['28', ''],
#    'venue': 'Loughborough',
#    'meeting': 'CAU Inter County Championships (Inc British Athletics Cross Challenge)',
#    'date': '7 Mar 20'},
#   {'event': 'ZXC',
#    'value': '20:56',
#    'position': ['4', ''],
#    'venue': 'Colchester',
#    'meeting': 'Essex League',
#    'date': '11 Jan 20'},
#   {'event': '5KMT',
#    'value': '20:52',
#    'position': ['21', ''],
#    'venue': 'Basildon',
#    'meeting': 'Crown to Crown Good Friday 5K',
#    'date': '19 Apr 19'},
#   {'event': '5KXC',
#    'value': '20:32',
#    'position': ['10', ''],
#    'venue': 'One Tree Hill',
#    'meeting': 'Essex League',
#    'date': '12 Oct 19'},
#   {'event': '6KXC',
#    'value': '25:41',
#    'position': ['86', ''],
#    'venue': 'Loughborough',
#    'meeting': 'CAU Inter County Championships  (Inc British Athletics Cross Challenge)',
#    'date': '9 Mar 19'},
#   {'event': '8KXC',
#    'value': '35:22',
#    'position': ['7', ''],
#    'venue': 'Chelmsford',
#    'meeting': 'Essex County U17 / U20 / Senior Championships',
#    'date': '5 Jan 19'},
#   {'event': 'ZXC',
#    'value': '14:07',
#    'position': ['9', ''],
#    'venue': 'Hockley',
#    'meeting': "Essex County Schools' Championships",
#    'date': '19 Jan 19'},
#   {'event': 'ZXC',
#    'value': '21:36',
#    'position': ['3', ''],
#    'venue': 'Writtle College',
#    'meeting': 'Essex League',
#    'date': '14 Dec 19'},
#   {'event': 'ZXC',
#    'value': '21:46',
#    'position': ['6', ''],
#    'venue': 'Basildon',
#    'meeting': 'Essex League',
#    'date': '2 Feb 19'},
#   {'event': 'ZXC',
#    'value': '24:02',
#    'position': ['5', ''],
#    'venue': 'Chingford',
#    'meeting': 'Essex League',
#    'date': '12 Jan 19'},
#   {'event': '1500',
#    'value': '5:05.34',
#    'position': ['14', '4'],
#    'venue': 'Watford',
#    'meeting': 'Watford Open Graded Meeting',
#    'date': '27 Jun 18'},
#   {'event': '5KMT',
#    'value': '21:35',
#    'position': ['33', ''],
#    'venue': 'Basildon',
#    'meeting': 'Crown to Crown Boxing Day 5K',
#    'date': '26 Dec 18'},
#   {'event': '5KXC',
#    'value': '21:47',
#    'position': ['47', ''],
#    'venue': 'Braintree',
#    'meeting': 'Essex County U17 / U20 / Senior Championships',
#    'date': '6 Jan 18'},
#   {'event': '5KXC',
#    'value': '22:57',
#    'position': ['14', ''],
#    'venue': 'Hockley',
#    'meeting': 'Essex League',
#    'date': '27 Oct 18'},
#   {'event': 'parkrun',
#    'value': '21:46',
#    'position': ['5', ''],
#    'venue': 'Hadleigh',
#    'meeting': 'Hadleigh parkrun # 68',
#    'date': '24 Feb 18'},
#   {'event': '6KXC',
#    'value': '27:01',
#    'position': ['105', ''],
#    'venue': 'Oxford',
#    'meeting': "South of England Masters' & Inter Counties Championships",
#    'date': '8 Dec 18'},
#   {'event': 'ZXC',
#    'value': '20:05',
#    'position': ['7', ''],
#    'venue': 'One Tree Hill',
#    'meeting': 'Essex League',
#    'date': '10 Nov 18'},
#   {'event': 'ZXC',
#    'value': '21:26',
#    'position': ['5', ''],
#    'venue': 'Basildon',
#    'meeting': 'Essex League',
#    'date': '10 Feb 18'},
#   {'event': 'ZXC',
#    'value': '22:18',
#    'position': ['8', ''],
#    'venue': 'Horseheath',
#    'meeting': 'Essex League',
#    'date': '15 Dec 18'},
#   {'event': '1500',
#    'value': '5:19.97',
#    'position': ['7', ''],
#    'venue': 'Chelmsford',
#    'meeting': 'Essex County Schools Championships',
#    'date': '10 Jun 17'},
#   {'event': '3KXCL',
#    'value': '11:29',
#    'position': ['5', 'L1'],
#    'venue': 'North Ockendon',
#    'meeting': 'Essex County Relay Championships',
#    'date': '7 Oct 17'},
#   {'event': '4.1KXC',
#    'value': '17:06',
#    'position': ['56', ''],
#    'venue': 'Brands Hatch',
#    'meeting': "South East Schools' Championships",
#    'date': '4 Feb 17'},
#   {'event': 'parkrun',
#    'value': '20:15',
#    'position': ['17', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend parkrun # 237',
#    'date': '25 Mar 17'},
#   {'event': 'ZXC',
#    'value': '17:45',
#    'position': ['12', ''],
#    'venue': 'Colchester',
#    'meeting': "Essex County Schools' Championships",
#    'date': '21 Jan 17'},
#   {'event': 'ZXC',
#    'value': '21:10',
#    'position': ['6', ''],
#    'venue': 'Gloucester Park',
#    'meeting': 'Essex League',
#    'date': '11 Feb 17'},
#   {'event': 'ZXC',
#    'value': '21:34',
#    'position': ['19', ''],
#    'venue': 'Hockley',
#    'meeting': 'Essex League',
#    'date': '25 Nov 17'},
#   {'event': '800',
#    'value': '2:30.39',
#    'position': ['7', '7'],
#    'venue': 'Watford',
#    'meeting': 'Watford Open Graded Meeting',
#    'date': '13 Jul 16'},
#   {'event': '1500',
#    'value': '5:06.55',
#    'position': ['3', '3'],
#    'venue': 'Watford',
#    'meeting': 'Watford Open Graded Meeting',
#    'date': '27 Jul 16'},
#   {'event': '1500',
#    'value': '5:10.66',
#    'position': ['2', '2'],
#    'venue': 'Watford',
#    'meeting': 'Watford Open Graded Meeting',
#    'date': '1 Jun 16'},
#   {'event': '1500',
#    'value': '5:12.01',
#    'position': ['6', ''],
#    'venue': 'Chelmsford',
#    'meeting': 'Essex County Schools Championships',
#    'date': '11 Jun 16'},
#   {'event': '4KXC',
#    'value': '15:48',
#    'position': ['52', ''],
#    'venue': 'Bexhill',
#    'meeting': "South East Schools' Inter Counties",
#    'date': '6 Feb 16'},
#   {'event': '4KXC',
#    'value': '19:38',
#    'position': ['178', ''],
#    'venue': 'Birmingham',
#    'meeting': 'CAU Inter County Championships (Inc British Athletics Cross Challenge)',
#    'date': '12 Mar 16'},
#   {'event': '4.3KXC',
#    'value': '18:35',
#    'position': ['12', ''],
#    'venue': 'Colchester',
#    'meeting': "Essex County Schools' Championships",
#    'date': '23 Jan 16'},
#   {'event': '5KXC',
#    'value': '22:13',
#    'position': ['11', ''],
#    'venue': 'Horseheath',
#    'meeting': 'Essex League',
#    'date': '19 Nov 16'},
#   {'event': 'parkrun',
#    'value': '21:03',
#    'position': ['5', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 62',
#    'date': '16 Apr 16'},
#   {'event': 'ZXC',
#    'value': '16:31',
#    'position': ['7', ''],
#    'venue': 'Colchester',
#    'meeting': 'Essex League',
#    'date': '7 Feb 16'},
#   {'event': 'ZXC',
#    'value': '19:01',
#    'position': ['8', ''],
#    'venue': 'Chingford',
#    'meeting': 'Essex League',
#    'date': '2 Jan 16'},
#   {'event': 'ZXC',
#    'value': '20:49',
#    'position': ['13', ''],
#    'venue': 'Thurrock',
#    'meeting': 'Essex League',
#    'date': '8 Oct 16'},
#   {'event': '200',
#    'value': '30.4',
#    'position': ['6', 'A'],
#    'venue': 'Grays',
#    'meeting': "Eastern Young Athletes' League",
#    'date': '19 Apr 15'},
#   {'event': '800',
#    'value': '2:34.47',
#    'position': ['3', '1'],
#    'venue': 'Watford',
#    'meeting': 'Watford Open Graded Meeting',
#    'date': '15 Jul 15'},
#   {'event': '800',
#    'value': '2:38.84',
#    'position': ['9', '3'],
#    'venue': 'Woodford',
#    'meeting': 'Woodford Green Open',
#    'date': '9 Jun 15'},
#   {'event': '800',
#    'value': '2:39.2',
#    'position': ['5', 'A'],
#    'venue': 'Grays',
#    'meeting': "Eastern Young Athletes' League",
#    'date': '19 Apr 15'},
#   {'event': '1500',
#    'value': '5:16.77',
#    'position': ['4', '2'],
#    'venue': 'Watford',
#    'meeting': 'Watford Open Graded Meeting',
#    'date': '29 Jul 15'},
#   {'event': '1500',
#    'value': '5:23.02',
#    'position': ['7', '2'],
#    'venue': 'Watford',
#    'meeting': 'Watford Open Graded Meeting',
#    'date': '26 Aug 15'},
#   {'event': 'ZXC',
#    'value': '14:24',
#    'position': ['18', ''],
#    'venue': 'Colchester',
#    'meeting': "Essex Schools' Championships",
#    'date': '17 Jan 15'},
#   {'event': 'ZXC',
#    'value': '16:26',
#    'position': ['8', ''],
#    'venue': 'Hockley',
#    'meeting': 'Essex League',
#    'date': '31 Oct 15'},
#   {'event': 'ZXC',
#    'value': '16:56',
#    'position': ['8', ''],
#    'venue': 'Colchester',
#    'meeting': 'Essex League',
#    'date': '31 Jan 15'},
#   {'event': 'ZXC',
#    'value': '17:09',
#    'position': ['7', ''],
#    'venue': 'Horseheath',
#    'meeting': 'Essex League',
#    'date': '14 Nov 15'},
#   {'event': 'ZXC',
#    'value': '19:28',
#    'position': ['13', ''],
#    'venue': 'Chingford',
#    'meeting': 'Essex League',
#    'date': '10 Jan 15'},
#   {'event': 'ZXC',
#    'value': '19:43',
#    'position': ['14', ''],
#    'venue': 'Woodford',
#    'meeting': 'Essex County Championships',
#    'date': '3 Jan 15'},
#   {'event': 'ZXC',
#    'value': '19:56',
#    'position': ['8', ''],
#    'venue': 'One Tree Hill',
#    'meeting': 'Essex League',
#    'date': '10 Oct 15'},
#   {'event': 'ZXC',
#    'value': '14:15',
#    'position': ['22', ''],
#    'venue': 'Chelmsford',
#    'meeting': 'Essex League',
#    'date': '15 Nov 14'},
#   {'event': 'ZXC',
#    'value': '19:19',
#    'position': ['22', ''],
#    'venue': 'Thurrock',
#    'meeting': 'Essex League',
#    'date': '18 Oct 14'},
#   {'event': 'ZXCL',
#    'value': '14:43',
#    'position': ['7', 'L2'],
#    'venue': 'Hockley',
#    'meeting': 'Essex County Relay Championships',
#    'date': '27 Sep 14'}],
#  'rankings': [{'event': '800',
#    'age group': 'U15',
#    'year': '2015',
#    'rank': '704'},
#   {'event': '1500', 'age group': 'U15', 'year': '2015', 'rank': '490'},
#   {'event': '1500', 'age group': 'U17', 'year': '2016', 'rank': '267'},
#   {'event': '1500', 'age group': 'U20', 'year': '2018', 'rank': '195'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': '2022', 'rank': '2473'}],
#  'coaching': []}

# %%
from athletes import search_athletes

search_athletes(firstname='dy',club='southend AC')
# Out:
# [{'firstname': 'Dylan',
#   'surname': 'Schubert',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Southend',
#   'athlete_id': '1125172'}]

# %%
from athletes import get_athlete
get_athlete(1125172)
# Out:
# {'club': 'Southend',
#  'gender': 'Male',
#  'age_group': 'SEN',
#  'county': 'Essex',
#  'region': 'East',
#  'nation': 'England',
#  'lead coach': 'Unknown',
#  'about': 'Login to add some details about this athlete',
#  'pb': [{'event': '3000', 'value': '9:15.77'},
#   {'event': '5K', 'value': '16:11'},
#   {'event': 'parkrun', 'value': '16:07'},
#   {'event': '10K', 'value': '33:49'},
#   {'event': 'HM', 'value': '74:38'}],
#  'performances': [{'event': '3000',
#    'value': '9:15.77',
#    'position': ['3', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend Open Graded Track Meeting',
#    'date': '30 May 24'},
#   {'event': '3000',
#    'value': '9:26.76',
#    'position': ['10', ''],
#    'venue': 'Chelmsford',
#    'meeting': 'Essex County Championships',
#    'date': '11 May 24'},
#   {'event': '3ML',
#    'value': '15:31',
#    'position': ['2', 'L2'],
#    'venue': 'Colchester',
#    'meeting': 'Essex & Suffolk County Relay Championships',
#    'date': '7 Apr 24'},
#   {'event': '5K',
#    'value': '16:11',
#    'position': ['44', 'R1'],
#    'venue': 'Battersea Park',
#    'meeting': 'Friday Night 5K Under the Lights',
#    'date': '15 Mar 24'},
#   {'event': '5KMT',
#    'value': '17:23',
#    'position': ['1', ''],
#    'venue': 'Basildon',
#    'meeting': 'Crown to Crown 5K Series',
#    'date': '29 Mar 24'},
#   {'event': 'parkrun',
#    'value': '16:07',
#    'position': ['1', ''],
#    'venue': 'Chalkwell Beach',
#    'meeting': 'Chalkwell Beach parkrun # 133',
#    'date': '20 Jan 24'},
#   {'event': '10K',
#    'value': '33:49',
#    'position': ['13', ''],
#    'venue': 'Little Bromley',
#    'meeting': 'Little Bromley 10K',
#    'date': '14 Apr 24'},
#   {'event': '12KXC',
#    'value': '45:57',
#    'position': ['26', ''],
#    'venue': 'Basildon',
#    'meeting': 'Essex County Championships',
#    'date': '6 Jan 24'},
#   {'event': '5K',
#    'value': '16:17',
#    'position': ['12', 'R2'],
#    'venue': 'Battersea Park',
#    'meeting': 'Friday Night 5K Under the Lights',
#    'date': '15 Sep 23'},
#   {'event': '5K',
#    'value': '16:28',
#    'position': ['36', ''],
#    'venue': 'Colchester',
#    'meeting': 'Colchester Friday Night Runs',
#    'date': '11 Aug 23'},
#   {'event': 'parkrun',
#    'value': '16:25',
#    'position': ['1', ''],
#    'venue': 'Chalkwell Beach',
#    'meeting': 'Chalkwell Beach parkrun # 81',
#    'date': '4 Feb 23'},
#   {'event': 'parkrun',
#    'value': '16:28',
#    'position': ['3', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend parkrun # 488',
#    'date': '13 May 23'},
#   {'event': 'parkrun',
#    'value': '16:33',
#    'position': ['2', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend parkrun # 487',
#    'date': '6 May 23'},
#   {'event': 'parkrun',
#    'value': '16:47',
#    'position': ['1', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend parkrun # 515',
#    'date': '18 Nov 23'},
#   {'event': 'parkrun',
#    'value': '17:07',
#    'position': ['2', ''],
#    'venue': 'Chalkwell Beach',
#    'meeting': 'Chalkwell Beach parkrun # 99',
#    'date': '10 Jun 23'},
#   {'event': 'parkrun',
#    'value': '18:33',
#    'position': ['2', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 338',
#    'date': '14 Jan 23'},
#   {'event': '4MXC',
#    'value': '24:40',
#    'position': ['2', ''],
#    'venue': 'Hadleigh',
#    'meeting': 'South Essex League',
#    'date': '26 Nov 23'},
#   {'event': '8KXC',
#    'value': '28:03',
#    'position': ['28', ''],
#    'venue': 'Hilly Fields',
#    'meeting': 'Essex League',
#    'date': '16 Dec 23'},
#   {'event': '10K',
#    'value': '34:06',
#    'position': ['19', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend 10K Classic',
#    'date': '1 Oct 23'},
#   {'event': '12KXC',
#    'value': '43:12',
#    'position': ['30', ''],
#    'venue': 'Basildon',
#    'meeting': 'Essex County Championships',
#    'date': '7 Jan 23'},
#   {'event': 'HM',
#    'value': '74:38',
#    'position': ['64', ''],
#    'venue': 'Bath',
#    'meeting': 'Bath Half Marathon',
#    'date': '15 Oct 23'},
#   {'event': 'HM',
#    'value': '74:57',
#    'position': ['4', ''],
#    'venue': 'Brentwood',
#    'meeting': 'Brentwood Half Marathon',
#    'date': '12 Mar 23'},
#   {'event': 'parkrun',
#    'value': '16:42',
#    'position': ['2', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend parkrun # 458',
#    'date': '22 Oct 22'},
#   {'event': 'parkrun',
#    'value': '17:28',
#    'position': ['4', ''],
#    'venue': 'Chalkwell Beach',
#    'meeting': 'Chalkwell Beach parkrun # 31',
#    'date': '5 Feb 22'},
#   {'event': 'parkrun',
#    'value': '18:06',
#    'position': ['2', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 302',
#    'date': '30 Apr 22'},
#   {'event': 'parkrun',
#    'value': '18:28',
#    'position': ['1', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 336',
#    'date': '31 Dec 22'},
#   {'event': '8KXC',
#    'value': '31:14',
#    'position': ['37', ''],
#    'venue': 'Epping Forest',
#    'meeting': 'Essex League',
#    'date': '12 Nov 22'},
#   {'event': '8KXC',
#    'value': '33:22',
#    'position': ['44', ''],
#    'venue': 'Writtle',
#    'meeting': 'Essex League',
#    'date': '19 Feb 22'},
#   {'event': '8.5KXC',
#    'value': '35:39',
#    'position': ['53', ''],
#    'venue': 'Hainault Forest',
#    'meeting': 'Essex League',
#    'date': '22 Jan 22'},
#   {'event': '10K',
#    'value': '35:10',
#    'position': ['9', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend 10K Classic',
#    'date': '18 Sep 22'},
#   {'event': '10KXC',
#    'value': '38:22',
#    'position': ['57', ''],
#    'venue': 'Basildon',
#    'meeting': 'Essex County U17 / U20 / Senior Championships',
#    'date': '8 Jan 22'},
#   {'event': 'HM',
#    'value': '81:24',
#    'position': ['26', ''],
#    'venue': 'Shoeburyness',
#    'meeting': 'Southend Half Marathon',
#    'date': '12 Jun 22'},
#   {'event': 'parkrun',
#    'value': '17:35',
#    'position': ['5', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend parkrun # 413',
#    'date': '4 Dec 21'},
#   {'event': 'parkrun',
#    'value': '18:45',
#    'position': ['2', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 282',
#    'date': '27 Nov 21'},
#   {'event': 'parkrun',
#    'value': '19:02',
#    'position': ['6', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 284',
#    'date': '11 Dec 21'},
#   {'event': 'parkrun',
#    'value': '19:22',
#    'position': ['2', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 268',
#    'date': '21 Aug 21'},
#   {'event': 'parkrun',
#    'value': '19:40',
#    'position': ['1', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 280',
#    'date': '13 Nov 21'},
#   {'event': 'parkrun',
#    'value': '19:48',
#    'position': ['2', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 266',
#    'date': '7 Aug 21'},
#   {'event': 'parkrun',
#    'value': '23:51',
#    'position': ['24', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 253',
#    'date': '4 Jan 20'},
#   {'event': 'parkrun',
#    'value': '25:40',
#    'position': ['46', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 214',
#    'date': '6 Apr 19'},
#   {'event': 'parkrun',
#    'value': '21:45',
#    'position': ['31', ''],
#    'venue': 'Southend',
#    'meeting': 'Southend parkrun # 305',
#    'date': '14 Jul 18'},
#   {'event': 'parkrun',
#    'value': '21:48',
#    'position': ['31', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 183',
#    'date': '8 Sep 18'},
#   {'event': 'parkrun',
#    'value': '21:52',
#    'position': ['14', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 192',
#    'date': '10 Nov 18'},
#   {'event': 'parkrun',
#    'value': '21:59',
#    'position': ['20', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 188',
#    'date': '13 Oct 18'},
#   {'event': 'parkrun',
#    'value': '22:03',
#    'position': ['18', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 190',
#    'date': '27 Oct 18'},
#   {'event': 'parkrun',
#    'value': '22:27',
#    'position': ['16', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 161',
#    'date': '24 Mar 18'},
#   {'event': 'parkrun',
#    'value': '22:28',
#    'position': ['12', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 155',
#    'date': '10 Feb 18'},
#   {'event': 'parkrun',
#    'value': '22:35',
#    'position': ['21', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 172',
#    'date': '9 Jun 18'},
#   {'event': 'parkrun',
#    'value': '22:48',
#    'position': ['25', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 173',
#    'date': '16 Jun 18'},
#   {'event': 'parkrun',
#    'value': '22:51',
#    'position': ['24', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 154',
#    'date': '3 Feb 18'},
#   {'event': 'parkrun',
#    'value': '22:52',
#    'position': ['32', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 177',
#    'date': '21 Jul 18'},
#   {'event': 'parkrun',
#    'value': '23:02',
#    'position': ['15', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 152',
#    'date': '20 Jan 18'},
#   {'event': 'parkrun',
#    'value': '23:21',
#    'position': ['33', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 153',
#    'date': '27 Jan 18'},
#   {'event': 'parkrun',
#    'value': '23:21',
#    'position': ['34', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 186',
#    'date': '29 Sep 18'},
#   {'event': 'parkrun',
#    'value': '24:11',
#    'position': ['21', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 160',
#    'date': '17 Mar 18'},
#   {'event': 'parkrun',
#    'value': '24:15',
#    'position': ['28', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 151',
#    'date': '13 Jan 18'},
#   {'event': 'parkrun',
#    'value': '24:16',
#    'position': ['38', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 150',
#    'date': '6 Jan 18'},
#   {'event': 'parkrun',
#    'value': '24:21',
#    'position': ['55', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 182',
#    'date': '1 Sep 18'},
#   {'event': 'parkrun',
#    'value': '24:23',
#    'position': ['29', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 158',
#    'date': '3 Mar 18'},
#   {'event': 'parkrun',
#    'value': '22:21',
#    'position': ['18', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 112',
#    'date': '8 Apr 17'},
#   {'event': 'parkrun',
#    'value': '22:22',
#    'position': ['20', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 106',
#    'date': '25 Feb 17'},
#   {'event': 'parkrun',
#    'value': '22:48',
#    'position': ['16', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 101',
#    'date': '21 Jan 17'},
#   {'event': 'parkrun',
#    'value': '23:36',
#    'position': ['31', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 120',
#    'date': '10 Jun 17'},
#   {'event': 'parkrun',
#    'value': '23:39',
#    'position': ['36', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 102',
#    'date': '28 Jan 17'},
#   {'event': 'parkrun',
#    'value': '23:51',
#    'position': ['33', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 124',
#    'date': '8 Jul 17'},
#   {'event': 'parkrun',
#    'value': '24:00',
#    'position': ['33', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 100',
#    'date': '14 Jan 17'},
#   {'event': 'parkrun',
#    'value': '24:22',
#    'position': ['35', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 110',
#    'date': '25 Mar 17'},
#   {'event': 'parkrun',
#    'value': '24:25',
#    'position': ['43', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 105',
#    'date': '18 Feb 17'},
#   {'event': 'parkrun',
#    'value': '24:34',
#    'position': ['45', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 111',
#    'date': '1 Apr 17'},
#   {'event': 'parkrun',
#    'value': '24:47',
#    'position': ['61', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 138',
#    'date': '14 Oct 17'},
#   {'event': 'parkrun',
#    'value': '24:59',
#    'position': ['45', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 144',
#    'date': '25 Nov 17'},
#   {'event': 'parkrun',
#    'value': '26:30',
#    'position': ['51', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 136',
#    'date': '30 Sep 17'},
#   {'event': 'parkrun',
#    'value': '22:25',
#    'position': ['18', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 88',
#    'date': '22 Oct 16'},
#   {'event': 'parkrun',
#    'value': '22:58',
#    'position': ['15', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 94',
#    'date': '3 Dec 16'},
#   {'event': 'parkrun',
#    'value': '23:08',
#    'position': ['15', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 92',
#    'date': '19 Nov 16'},
#   {'event': 'parkrun',
#    'value': '23:09',
#    'position': ['14', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 95',
#    'date': '10 Dec 16'},
#   {'event': 'parkrun',
#    'value': '23:15',
#    'position': ['31', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 64',
#    'date': '30 Apr 16'},
#   {'event': 'parkrun',
#    'value': '23:18',
#    'position': ['22', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 91',
#    'date': '12 Nov 16'},
#   {'event': 'parkrun',
#    'value': '23:47',
#    'position': ['42', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 87',
#    'date': '15 Oct 16'},
#   {'event': 'parkrun',
#    'value': '24:09',
#    'position': ['37', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 65',
#    'date': '7 May 16'},
#   {'event': 'parkrun',
#    'value': '24:41',
#    'position': ['42', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 63',
#    'date': '23 Apr 16'},
#   {'event': 'parkrun',
#    'value': '24:53',
#    'position': ['45', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 55',
#    'date': '27 Feb 16'},
#   {'event': 'parkrun',
#    'value': '25:07',
#    'position': ['51', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 89',
#    'date': '29 Oct 16'},
#   {'event': 'parkrun',
#    'value': '25:42',
#    'position': ['42', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 54',
#    'date': '20 Feb 16'},
#   {'event': 'parkrun',
#    'value': '24:40',
#    'position': ['30', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 14',
#    'date': '9 May 15'},
#   {'event': 'parkrun',
#    'value': '25:11',
#    'position': ['32', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 34',
#    'date': '3 Oct 15'},
#   {'event': 'parkrun',
#    'value': '26:18',
#    'position': ['43', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 30',
#    'date': '5 Sep 15'},
#   {'event': 'parkrun',
#    'value': '27:18',
#    'position': ['66', ''],
#    'venue': 'Hockley Woods',
#    'meeting': 'Hockley Woods parkrun # 28',
#    'date': '22 Aug 15'}],
#  'rankings': [{'event': '3000',
#    'age group': 'ALL',
#    'year': '2024',
#    'rank': '873'},
#   {'event': '5K', 'age group': 'U23', 'year': '2023', 'rank': '280'},
#   {'event': '5K', 'age group': 'ALL', 'year': '2023', 'rank': '2107'},
#   {'event': '5K', 'age group': 'U23', 'year': '2024', 'rank': '250'},
#   {'event': '5K', 'age group': 'ALL', 'year': '2024', 'rank': '1529'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': '2022', 'rank': '2524'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': '2023', 'rank': '1757'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': '2024', 'rank': '588'},
#   {'event': '10K', 'age group': 'U23', 'year': '2022', 'rank': '250'},
#   {'event': '10K', 'age group': 'U23', 'year': '2023', 'rank': '208'},
#   {'event': '10K', 'age group': 'ALL', 'year': '2023', 'rank': '2250'},
#   {'event': '10K', 'age group': 'ALL', 'year': '2023', 'rank': '2250'},
#   {'event': '10K', 'age group': 'ALL', 'year': '2024', 'rank': '1092'},
#   {'event': '10K', 'age group': 'U23', 'year': '2024', 'rank': '103'},
#   {'event': 'HM', 'age group': 'U23', 'year': '2022', 'rank': '182'},
#   {'event': 'HM', 'age group': 'ALL', 'year': '2022', 'rank': '4866'},
#   {'event': 'HM', 'age group': 'U23', 'year': '2023', 'rank': '91'},
#   {'event': 'HM', 'age group': 'ALL', 'year': '2023', 'rank': '1491'}],
#  'coaching': []}

# %%
from athletes import search_athletes

search_athletes(surname='c',club='aldershot')
#search_athletes(club='leigh-on-sea')
# Out:
# [{'firstname': 'Izzy',
#   'surname': 'Cahill',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '527901'},
#  {'firstname': 'Howard',
#   'surname': 'Calvert',
#   'track': 'V45',
#   'road': 'V45',
#   'xc': 'V45',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1235521'},
#  {'firstname': 'Willa',
#   'surname': 'Calvert',
#   'track': 'U15',
#   'road': 'U13',
#   'xc': 'U13',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1235522'},
#  {'firstname': 'Lourdes',
#   'surname': 'Camos',
#   'track': 'V50',
#   'road': 'V50',
#   'xc': 'V50',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District/Southern Counties Vets/Spain',
#   'athlete_id': '781388'},
#  {'firstname': 'Gerard',
#   'surname': 'Campbell',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/Manchester Uni',
#   'athlete_id': '507038'},
#  {'firstname': 'Ollie',
#   'surname': 'Campbell',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Cirencester/Aldershot, Farnham & District/Warwick Uni',
#   'athlete_id': '667544'},
#  {'firstname': 'Ruby',
#   'surname': 'Campbell',
#   'track': 'U17',
#   'road': 'U17',
#   'xc': 'U17',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '970241'},
#  {'firstname': 'Rebecca',
#   'surname': 'Cann',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '448847'},
#  {'firstname': 'Eoin',
#   'surname': 'Canning',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '646647'},
#  {'firstname': 'Benjamin',
#   'surname': 'Carpenter',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '753446'},
#  {'firstname': 'Rob',
#   'surname': 'Carr',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '43248'},
#  {'firstname': 'Matt',
#   'surname': 'Cartailler',
#   'track': 'V50',
#   'road': 'V50',
#   'xc': 'V50',
#   'sex': 'M',
#   'club': 'Guildford & Godalming/Aldershot, Farnham & District',
#   'athlete_id': '10127'},
#  {'firstname': 'Beth',
#   'surname': 'Carter',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': "Aldershot, Farnham & District/St. Mary's Uni",
#   'athlete_id': '13943'},
#  {'firstname': 'Lydia',
#   'surname': 'Carter',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '773902'},
#  {'firstname': 'Andrew',
#   'surname': 'Cartledge',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '863903'},
#  {'firstname': 'Lois',
#   'surname': 'Carty',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '779084'},
#  {'firstname': 'Elysia',
#   'surname': 'Castles-Oliver',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '667729'},
#  {'firstname': 'Adam',
#   'surname': 'Cauldwell',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '56609'},
#  {'firstname': 'Lizzie',
#   'surname': 'Cave',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District/Birmingham Uni',
#   'athlete_id': '7453'},
#  {'firstname': 'Jessica',
#   'surname': 'Cawley',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '31016'},
#  {'firstname': 'Amy',
#   'surname': 'Chalke',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '102471'},
#  {'firstname': 'Phillip',
#   'surname': 'Chalke',
#   'track': 'V55',
#   'road': 'V55',
#   'xc': 'V55',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/Southern Counties Vets/Police',
#   'athlete_id': '108942'},
#  {'firstname': 'Eleanor',
#   'surname': 'Champion',
#   'track': 'U17',
#   'road': 'U15',
#   'xc': 'U15',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '985668'},
#  {'firstname': 'Tom',
#   'surname': 'Chandler',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/Bath Uni',
#   'athlete_id': '1009129'},
#  {'firstname': 'Hannah',
#   'surname': 'Chapman',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '291964'},
#  {'firstname': 'Leigh',
#   'surname': 'Chapman',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '48683'},
#  {'firstname': 'Georgie',
#   'surname': 'Charles',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '436741'},
#  {'firstname': 'Callum',
#   'surname': 'Charleston',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': "Aldershot, Farnham & District/St. Mary's Uni",
#   'athlete_id': '81605'},
#  {'firstname': 'Maia',
#   'surname': 'Cheer',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '667914'},
#  {'firstname': 'Molly',
#   'surname': 'Childerhouse',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '632752'},
#  {'firstname': 'Benjamin',
#   'surname': 'Chillery',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '646785'},
#  {'firstname': 'Christo',
#   'surname': 'Chilton',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '656448'},
#  {'firstname': 'Kane',
#   'surname': 'Chinyou',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '600646'},
#  {'firstname': 'Billy',
#   'surname': 'Chipchase',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1229222'},
#  {'firstname': 'Becky',
#   'surname': 'Chissell',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '292355'},
#  {'firstname': 'Max',
#   'surname': 'Chitty',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '774831'},
#  {'firstname': 'Jacob',
#   'surname': 'Chiverton',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '292375'},
#  {'firstname': 'Matthew',
#   'surname': 'Chung',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '532079'},
#  {'firstname': 'Joshua',
#   'surname': 'Clark',
#   'track': 'U17',
#   'road': 'U17',
#   'xc': 'U17',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '985817'},
#  {'firstname': 'Adam',
#   'surname': 'Clarke',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': "Aldershot, Farnham & District/St. Mary's Uni",
#   'athlete_id': '8365'},
#  {'firstname': 'Dylan',
#   'surname': 'Clarke',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1068627'},
#  {'firstname': 'Fiona',
#   'surname': 'Clarke',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '46075'},
#  {'firstname': 'Steve',
#   'surname': 'Clarke',
#   'track': 'V50',
#   'road': 'V50',
#   'xc': 'V50',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '141712'},
#  {'firstname': 'Alex',
#   'surname': 'Clayton',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '203263'},
#  {'firstname': 'Daniel',
#   'surname': 'Clayton',
#   'track': 'U11',
#   'road': 'U11',
#   'xc': 'U11',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1217658'},
#  {'firstname': 'Lindi',
#   'surname': 'Clayton',
#   'track': 'V40',
#   'road': 'V40',
#   'xc': 'V40',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1203240'},
#  {'firstname': 'Thomas',
#   'surname': 'Clayton',
#   'track': 'V40',
#   'road': 'V40',
#   'xc': 'V40',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1116724'},
#  {'firstname': 'Paul',
#   'surname': 'Clement',
#   'track': 'V40',
#   'road': 'V40',
#   'xc': 'V40',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '114170'},
#  {'firstname': 'Alistair',
#   'surname': 'Clements',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1235529'},
#  {'firstname': 'Mark',
#   'surname': 'Clews',
#   'track': 'V65',
#   'road': 'V65',
#   'xc': 'V65',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '30641'},
#  {'firstname': 'Valerie',
#   'surname': 'Clews',
#   'track': 'V60',
#   'road': 'V60',
#   'xc': 'V60',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '15514'},
#  {'firstname': 'Victoria',
#   'surname': 'Clews',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1981'},
#  {'firstname': 'Dawn',
#   'surname': 'Cobbett',
#   'track': 'V65',
#   'road': 'V65',
#   'xc': 'V65',
#   'sex': 'W',
#   'club': 'Run Academy Worthing/Aldershot, Farnham & District',
#   'athlete_id': '120577'},
#  {'firstname': 'Oliver',
#   'surname': 'Cobbett',
#   'track': 'U15',
#   'road': 'U13',
#   'xc': 'U13',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1123017'},
#  {'firstname': 'Kyle',
#   'surname': 'Cochrane',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '914652'},
#  {'firstname': 'Caroline',
#   'surname': 'Cockle',
#   'track': 'V60',
#   'road': 'V60',
#   'xc': 'V60',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '203681'},
#  {'firstname': 'Eugenie',
#   'surname': 'Cockle',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District/Exeter Uni',
#   'athlete_id': '203508'},
#  {'firstname': 'Gus',
#   'surname': 'Cockle',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/UCL',
#   'athlete_id': '72972'},
#  {'firstname': 'Karel',
#   'surname': 'Coetzee',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '608003'},
#  {'firstname': 'Bailey',
#   'surname': 'Coles',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '782713'},
#  {'firstname': 'Andrew',
#   'surname': 'Collins',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '85006'},
#  {'firstname': 'Angel',
#   'surname': 'Collins',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': "Aldershot, Farnham & District/St. Mary's Uni",
#   'athlete_id': '84236'},
#  {'firstname': 'Matilda',
#   'surname': 'Collins',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '789925'},
#  {'firstname': 'Justin',
#   'surname': 'Colyer',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '699326'},
#  {'firstname': 'Steven',
#   'surname': 'Connor',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '19460'},
#  {'firstname': 'Michael',
#   'surname': 'Conoley',
#   'track': 'V65',
#   'road': 'V65',
#   'xc': 'V65',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '218696'},
#  {'firstname': 'Tobias',
#   'surname': 'Conoley',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '449394'},
#  {'firstname': 'Anna',
#   'surname': 'Constantine-Aspinall',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '608186'},
#  {'firstname': 'Umberto',
#   'surname': 'Contran',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/Italy',
#   'athlete_id': '782189'},
#  {'firstname': 'Andrew',
#   'surname': 'Conway',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '3224'},
#  {'firstname': 'Leon',
#   'surname': 'Conway',
#   'track': 'V50',
#   'road': 'V50',
#   'xc': 'V50',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '449406'},
#  {'firstname': 'Ruby',
#   'surname': 'Conway',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '384822'},
#  {'firstname': 'Matthew',
#   'surname': 'Cook',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '532492'},
#  {'firstname': 'Amy',
#   'surname': 'Cooper',
#   'track': 'U20',
#   'road': 'U17',
#   'xc': 'U17',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '785094'},
#  {'firstname': 'Grace',
#   'surname': 'Cooper',
#   'track': 'U17',
#   'road': 'U15',
#   'xc': 'U15',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '970608'},
#  {'firstname': 'Joseph',
#   'surname': 'Cooper',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '728054'},
#  {'firstname': 'Rosy',
#   'surname': 'Cooper',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District/Millfield Sch',
#   'athlete_id': '6554'},
#  {'firstname': 'Scarlet',
#   'surname': 'Cooper',
#   'track': 'U17',
#   'road': 'U17',
#   'xc': 'U17',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '970621'},
#  {'firstname': 'Simon',
#   'surname': 'Cooper',
#   'track': 'V50',
#   'road': 'V50',
#   'xc': 'V50',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '190074'},
#  {'firstname': 'Lucy',
#   'surname': 'Copley',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '2843'},
#  {'firstname': 'Carl',
#   'surname': 'Corcoran',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '88326'},
#  {'firstname': 'Macy',
#   'surname': 'Corke',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '532606'},
#  {'firstname': 'Sophie',
#   'surname': 'Cornall',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '864663'},
#  {'firstname': 'Karl',
#   'surname': 'Corpes',
#   'track': 'V55',
#   'road': 'V55',
#   'xc': 'V55',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '3383'},
#  {'firstname': 'Ben',
#   'surname': 'Cossey',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '668546'},
#  {'firstname': 'Leon',
#   'surname': 'Cosway',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '532644'},
#  {'firstname': 'Brendan',
#   'surname': 'Cottrell',
#   'track': 'V50',
#   'road': 'V50',
#   'xc': 'V50',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '116890'},
#  {'firstname': 'Ethan',
#   'surname': 'Cottrell',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '970655'},
#  {'firstname': 'Paul',
#   'surname': 'Couldridge',
#   'track': 'V50',
#   'road': 'V50',
#   'xc': 'V50',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/Army',
#   'athlete_id': '4563'},
#  {'firstname': 'James',
#   'surname': 'Coule',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '878234'},
#  {'firstname': 'Robbie',
#   'surname': 'Coupland',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '294786'},
#  {'firstname': 'Jack',
#   'surname': 'Court',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '82188'},
#  {'firstname': 'Jess',
#   'surname': 'Court',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '851690'},
#  {'firstname': 'Ben',
#   'surname': 'Coverdale',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '53630'},
#  {'firstname': 'Lilly',
#   'surname': 'Coward',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '83178'},
#  {'firstname': 'Alexander',
#   'surname': 'Cox',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '449553'},
#  {'firstname': 'Isabel',
#   'surname': 'Cox',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '532724'},
#  {'firstname': 'James',
#   'surname': 'Cox',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '668644'},
#  {'firstname': 'Josie',
#   'surname': 'Cox',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District/Birmingham Uni',
#   'athlete_id': '881692'},
#  {'firstname': 'Laurence',
#   'surname': 'Cox',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '325'},
#  {'firstname': 'Lewis',
#   'surname': 'Cox',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '31852'},
#  {'firstname': 'Marc',
#   'surname': 'Craib',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '210895'},
#  {'firstname': 'Sam',
#   'surname': 'Crawford',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '4085'},
#  {'firstname': 'Ryan',
#   'surname': 'Crawte',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '118111'},
#  {'firstname': 'Nathan',
#   'surname': 'Creamer',
#   'track': 'U11',
#   'road': 'U11',
#   'xc': 'U11',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1192407'},
#  {'firstname': 'Caitlin',
#   'surname': 'Critchley',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '295413'},
#  {'firstname': 'Harry',
#   'surname': 'Critchley',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '295417'},
#  {'firstname': 'Samuel',
#   'surname': 'Critchley',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '295421'},
#  {'firstname': 'Art',
#   'surname': 'Croasdale',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '446422'},
#  {'firstname': 'Tom',
#   'surname': 'Cropp',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '27987'},
#  {'firstname': 'Charlie',
#   'surname': 'Cross',
#   'track': 'U15',
#   'road': 'U15',
#   'xc': 'U15',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1094072'},
#  {'firstname': 'Ellis',
#   'surname': 'Cross',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': "Aldershot, Farnham & District/St. Mary's Uni",
#   'athlete_id': '67150'},
#  {'firstname': 'Finlay',
#   'surname': 'Cross',
#   'track': 'U23',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/Brunel Uni London/Ealing Southall & Middx',
#   'athlete_id': '557167'},
#  {'firstname': 'Gabriella',
#   'surname': 'Croton',
#   'track': 'U20',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '728401'},
#  {'firstname': 'George',
#   'surname': 'Croton',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '449683'},
#  {'firstname': 'Murray',
#   'surname': 'Croton',
#   'track': 'V55',
#   'road': 'V55',
#   'xc': 'V55',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '624043'},
#  {'firstname': 'Caroline',
#   'surname': 'Croucher',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '223182'},
#  {'firstname': 'Felicity',
#   'surname': 'Croucher',
#   'track': 'U15',
#   'road': 'U13',
#   'xc': 'U13',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1107568'},
#  {'firstname': 'Martha',
#   'surname': 'Cruikshanks',
#   'track': 'U17',
#   'road': 'U15',
#   'xc': 'U15',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '906406'},
#  {'firstname': 'Oliver',
#   'surname': 'Cullinane',
#   'track': 'U15',
#   'road': 'U15',
#   'xc': 'U15',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1047408'},
#  {'firstname': 'Penelope',
#   'surname': 'Cummings',
#   'track': 'V45',
#   'road': 'V45',
#   'xc': 'V45',
#   'sex': 'W',
#   'club': 'Herne Hill/Aldershot, Farnham & District/Veterans',
#   'athlete_id': '84928'},
#  {'firstname': 'Adrian',
#   'surname': 'Cunningham',
#   'track': 'U13',
#   'road': 'U13',
#   'xc': 'U13',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '1109868'},
#  {'firstname': 'Ernie',
#   'surname': 'Cunningham',
#   'track': 'V75',
#   'road': 'V75',
#   'xc': 'V75',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '67277'},
#  {'firstname': 'Harrison',
#   'surname': 'Curling',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/Isle of Wight',
#   'athlete_id': '113394'},
#  {'firstname': 'Rosie',
#   'surname': 'Curling',
#   'track': 'V40',
#   'road': 'V40',
#   'xc': 'V40',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District/Belgrave/Army',
#   'athlete_id': '48621'},
#  {'firstname': 'Julia',
#   'surname': 'Curry',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '805265'},
#  {'firstname': 'Nick',
#   'surname': 'Curtis',
#   'track': 'V35',
#   'road': 'V35',
#   'xc': 'V35',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District/Army',
#   'athlete_id': '551835'},
#  {'firstname': 'Daniel',
#   'surname': 'Cvetkovic',
#   'track': 'U23',
#   'road': 'U20',
#   'xc': 'U20',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '526657'},
#  {'firstname': 'Ella',
#   'surname': 'Cvetkovic',
#   'track': 'SEN',
#   'road': 'U23',
#   'xc': 'U23',
#   'sex': 'W',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '296121'},
#  {'firstname': 'Jake',
#   'surname': 'Cvetkovic',
#   'track': 'SEN',
#   'road': 'SEN',
#   'xc': 'SEN',
#   'sex': 'M',
#   'club': 'Aldershot, Farnham & District',
#   'athlete_id': '296122'}]

# %%
from athletes import get_athlete
get_athlete(1009129)
# Out:
# {'club': 'Aldershot, Farnham & District/Bath Uni',
#  'gender': 'Male',
#  'age_group': 'U23',
#  'county': 'Surrey',
#  'region': 'South East',
#  'nation': 'England',
#  'lead coach': 'Mick Woods2022-Previous Lead',
#  'about': 'Login to add some details about this athlete',
#  'pb': [{'event': '1500', 'value': '3:57.67'},
#   {'event': 'Mile', 'value': '4:19.88'},
#   {'event': '3000', 'value': '8:18.90'},
#   {'event': '5000', 'value': '14:25.84'},
#   {'event': '5K', 'value': '14:29'},
#   {'event': 'parkrun', 'value': '15:17'},
#   {'event': '10K', 'value': '32:05'}],
#  'performances': [{'event': '1500',
#    'value': '3:57.67',
#    'position': ['3', '12'],
#    'venue': 'Wimbledon',
#    'meeting': 'Hercules Wimbledon 1500m Festival Night',
#    'date': '29 May 24'},
#   {'event': '1500',
#    'value': '3:58.08',
#    'position': ['7', 'A'],
#    'venue': 'Winchester',
#    'meeting': 'BMC Regional Races',
#    'date': '3 Jul 24'},
#   {'event': '1500',
#    'value': '4:00.32',
#    'position': ['1', '8'],
#    'venue': 'Aldershot',
#    'meeting': 'Aldershot Farnham & District Open Meetings Summer',
#    'date': '20 Jun 24'},
#   {'event': '3000',
#    'value': '8:18.90',
#    'position': ['15', '10'],
#    'venue': 'Wimbledon',
#    'meeting': 'Hercules Wimbledon 3000m Night of Races',
#    'date': '12 Jun 24'},
#   {'event': '5000',
#    'value': '14:25.84',
#    'position': ['5', '9'],
#    'venue': 'Wimbledon',
#    'meeting': 'Wimbledon 5000m Festival Night',
#    'date': '3 Aug 24'},
#   {'event': '5000',
#    'value': '14:27.87',
#    'position': ['2', '2'],
#    'venue': 'Sportcity',
#    'meeting': 'BUCS Athletics: Outdoor Championships',
#    'date': '6 May 24'},
#   {'event': '5000',
#    'value': '15:01.39',
#    'position': ['1', ''],
#    'venue': 'Eton',
#    'meeting': 'Southern U20/Senior & U15/U17 3000m Championships',
#    'date': '8 Jun 24'},
#   {'event': '5000',
#    'value': '15:04.15',
#    'position': ['20', '5'],
#    'venue': 'Battersea Park',
#    'meeting': 'Comeback 5000m #4 X Sportsshoes',
#    'date': '26 Apr 24'},
#   {'event': '5K',
#    'value': '14:29',
#    'position': ['19', 'R09'],
#    'venue': 'Leicester',
#    'meeting': 'Podium Festival 5K',
#    'date': '16 Mar 24'},
#   {'event': '5K',
#    'value': '14:29',
#    'position': ['12', 'W3'],
#    'venue': 'Bath',
#    'meeting': 'Bristol Track Club Race Day 3K / 5K',
#    'date': '13 Apr 24'},
#   {'event': 'parkrun',
#    'value': '15:17',
#    'position': ['1', ''],
#    'venue': 'Central, Plymouth',
#    'meeting': 'Central, Plymouth parkrun # 134',
#    'date': '27 Jul 24'},
#   {'event': 'parkrun',
#    'value': '15:19',
#    'position': ['1', ''],
#    'venue': 'Five Arches',
#    'meeting': 'Five Arches parkrun # 22',
#    'date': '10 Feb 24'},
#   {'event': 'parkrun',
#    'value': '15:26',
#    'position': ['1', ''],
#    'venue': 'Leicester Victoria',
#    'meeting': 'Leicester Victoria parkrun # 371',
#    'date': '22 Jun 24'},
#   {'event': 'parkrun',
#    'value': '15:44',
#    'position': ['1', ''],
#    'venue': 'Harcourt Hill',
#    'meeting': 'Harcourt Hill parkrun # 418',
#    'date': '10 Aug 24'},
#   {'event': 'parkrun',
#    'value': '16:19',
#    'position': ['1', ''],
#    'venue': 'Bath Skyline',
#    'meeting': 'Bath Skyline parkrun # 409',
#    'date': '20 Jan 24'},
#   {'event': 'parkrun',
#    'value': '16:20',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 194',
#    'date': '1 Jun 24'},
#   {'event': '8KXC',
#    'value': '24:39',
#    'position': ['11', ''],
#    'venue': 'Beckenham Place',
#    'meeting': 'South of England Championships',
#    'date': '27 Jan 24'},
#   {'event': '8.7KL',
#    'value': '27:14',
#    'position': ['6', 'L07'],
#    'venue': 'Milton Keynes',
#    'meeting': "Southern Men's 12-Stage Relays",
#    'date': '24 Mar 24'},
#   {'event': '9.69KXC',
#    'value': '36:34',
#    'position': ['53', ''],
#    'venue': 'Leeds',
#    'meeting': 'BUCS Cross Country Championships',
#    'date': '3 Feb 24'},
#   {'event': '9.8KXC',
#    'value': '32:57',
#    'position': ['2', ''],
#    'venue': 'Pittville Park',
#    'meeting': 'Gloucestershire League',
#    'date': '17 Feb 24'},
#   {'event': '10K',
#    'value': '32:05',
#    'position': ['2', ''],
#    'venue': 'Walton-on-Thames',
#    'meeting': 'Elmbridge 10K',
#    'date': '21 Jul 24'},
#   {'event': '10KXC',
#    'value': '28:48',
#    'position': ['63', ''],
#    'venue': 'Wollaton Park',
#    'meeting': 'CAU Inter County Championships (inc British Athletics Cross Challenge)',
#    'date': '9 Mar 24'},
#   {'event': '12.2KXC',
#    'value': '42:32',
#    'position': ['12', ''],
#    'venue': 'Dorking',
#    'meeting': 'Surrey County Championships',
#    'date': '7 Jan 24'},
#   {'event': '1500',
#    'value': '4:04.00',
#    'position': ['4m', '11'],
#    'venue': 'Wimbledon',
#    'meeting': 'Dave Clarke 1 Mile Night (+ 1500m split)',
#    'date': '28 Jun 23'},
#   {'event': '1500',
#    'value': '4:06.31',
#    'position': ['10', '7'],
#    'venue': 'Aldershot',
#    'meeting': 'Aldershot, Farnham & District Open Meeting',
#    'date': '8 Jun 23'},
#   {'event': '1500',
#    'value': '4:06.38',
#    'position': ['14', 'A'],
#    'venue': 'Wormwood Scrubs',
#    'meeting': 'BMC Regional Races',
#    'date': '21 Jun 23'},
#   {'event': 'Mile',
#    'value': '4:19.88',
#    'position': ['2', '11'],
#    'venue': 'Wimbledon',
#    'meeting': 'Dave Clarke 1 Mile Night (+ 1500m split)',
#    'date': '28 Jun 23'},
#   {'event': '3000',
#    'value': '8:35.65',
#    'position': ['2', '6'],
#    'venue': 'Wimbledon',
#    'meeting': 'Hercules Wimbledon 3000m Festival Night - sponsored by Tripadvisor',
#    'date': '7 Jun 23'},
#   {'event': '3000',
#    'value': '8:51.58',
#    'position': ['2', ''],
#    'venue': 'Kingston',
#    'meeting': 'Surrey County Championships',
#    'date': '14 May 23'},
#   {'event': '5000',
#    'value': '14:55.03',
#    'position': ['2', ''],
#    'venue': 'Walton',
#    'meeting': 'South of England Senior/U20 Championships',
#    'date': '3 Jun 23'},
#   {'event': '5000',
#    'value': '14:57.87',
#    'position': ['8', ''],
#    'venue': 'Chelmsford',
#    'meeting': 'England Athletics U20/U23 Open Championships',
#    'date': '17 Jun 23'},
#   {'event': '3KXCL',
#    'value': '9:09',
#    'position': ['11', 'L01'],
#    'venue': 'Mansfield',
#    'meeting': 'ECCA National Cross Country Relays',
#    'date': '4 Nov 23'},
#   {'event': '5K',
#    'value': '14:44',
#    'position': ['16', 'W3'],
#    'venue': 'Battersea Park',
#    'meeting': 'Friday Night 5K Under the Lights',
#    'date': '21 Apr 23'},
#   {'event': 'parkrun',
#    'value': '15:51',
#    'position': ['2', ''],
#    'venue': 'Bushy Park',
#    'meeting': 'Bushy Park parkrun # 940',
#    'date': '22 Jul 23'},
#   {'event': 'parkrun',
#    'value': '22:15',
#    'position': ['323', ''],
#    'venue': 'Bushy Park',
#    'meeting': 'Bushy Park parkrun # 963',
#    'date': '25 Dec 23'},
#   {'event': 'parkrun',
#    'value': '22:43',
#    'position': ['58', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 141',
#    'date': '22 Apr 23'},
#   {'event': '5.08KL',
#    'value': '15:38',
#    'position': ['4', 'L08'],
#    'venue': 'Birmingham',
#    'meeting': "ERRA Men's National 12-Stage Relays",
#    'date': '15 Apr 23'},
#   {'event': '6KXC',
#    'value': '21:01',
#    'position': ['11', ''],
#    'venue': 'Croydon',
#    'meeting': 'Surrey County Championships',
#    'date': '7 Jan 23'},
#   {'event': '6.4KXC',
#    'value': '20:35',
#    'position': ['9', ''],
#    'venue': 'Cardiff',
#    'meeting': 'British Athletics Cross Challenge (inc John H Collins Gwent League)',
#    'date': '11 Nov 23'},
#   {'event': '6.7KXC',
#    'value': '21:14',
#    'position': ['30', ''],
#    'venue': 'Sefton Park',
#    'meeting': 'British Athletics Cross Challenge (inc Euro Trials, L&D, Red Rose and Mid Lancs Leagues)',
#    'date': '25 Nov 23'},
#   {'event': '7.2KL',
#    'value': '22:38',
#    'position': ['9', 'L07'],
#    'venue': 'Olympic Park',
#    'meeting': "Southern Men's 12-Stage Relays",
#    'date': '2 Apr 23'},
#   {'event': '8KXC',
#    'value': '24:38',
#    'position': ['12', ''],
#    'venue': 'Beckenham Place',
#    'meeting': 'South of England Championships',
#    'date': '28 Jan 23'},
#   {'event': '8KXC',
#    'value': '30:06',
#    'position': ['25', ''],
#    'venue': 'Loughborough',
#    'meeting': 'CAU Inter County Championships (inc British Athletics Cross Challenge)',
#    'date': '11 Mar 23'},
#   {'event': '9.4KXC',
#    'value': '33:08',
#    'position': ['9', ''],
#    'venue': 'Gloucestershire',
#    'meeting': 'Gloucestershire League',
#    'date': '5 Mar 23'},
#   {'event': '9.75KXC',
#    'value': '32:52',
#    'position': ['3', ''],
#    'venue': 'Wellesley Woods',
#    'meeting': 'Hampshire League',
#    'date': '28 Oct 23'},
#   {'event': '10KXC',
#    'value': '35:02',
#    'position': ['45', ''],
#    'venue': 'Bolesworth Castle',
#    'meeting': 'ECCA Saucony English National Cross Country Championships',
#    'date': '25 Feb 23'},
#   {'event': '10.5KXC',
#    'value': '36:20',
#    'position': ['82', ''],
#    'venue': 'Pembrey Country Park',
#    'meeting': 'BUCS Cross Country Championships',
#    'date': '4 Feb 23'},
#   {'event': '1500',
#    'value': '4:10.50',
#    'position': ['7', '12'],
#    'venue': 'Watford',
#    'meeting': 'Watford Open Graded Meeting',
#    'date': '4 May 22'},
#   {'event': '3000',
#    'value': '8:55.14',
#    'position': ['5', ''],
#    'venue': 'Kingston',
#    'meeting': 'Surrey County Championships',
#    'date': '15 May 22'},
#   {'event': '3KXCL',
#    'value': '9:13',
#    'position': ['11', 'L2'],
#    'venue': 'Mansfield',
#    'meeting': 'ECCA Saucony English National Relay Championships',
#    'date': '5 Nov 22'},
#   {'event': 'parkrun',
#    'value': '16:08',
#    'position': ['1', ''],
#    'venue': 'Weymouth',
#    'meeting': 'Weymouth parkrun # 395',
#    'date': '30 Jul 22'},
#   {'event': 'parkrun',
#    'value': '16:08',
#    'position': ['1', ''],
#    'venue': 'Bath Skyline',
#    'meeting': 'Bath Skyline parkrun # 349',
#    'date': '3 Dec 22'},
#   {'event': 'parkrun',
#    'value': '16:17',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 92',
#    'date': '9 Apr 22'},
#   {'event': '6.4KXC',
#    'value': '19:35',
#    'position': ['16', ''],
#    'venue': 'Cardiff',
#    'meeting': 'Cardiff Cross Challenge',
#    'date': '15 Oct 22'},
#   {'event': '6.7KXC',
#    'value': '22:33',
#    'position': ['80', ''],
#    'venue': 'Sefton Park',
#    'meeting': 'British Athletics Cross Challenge (inc Euro Trials, L&D, Red Rose and Mid Lancs leagues)',
#    'date': '26 Nov 22'},
#   {'event': '6.9KXC',
#    'value': '23:11',
#    'position': ['8', ''],
#    'venue': 'Reigate',
#    'meeting': "Surrey County Schools' Championships",
#    'date': '22 Jan 22'},
#   {'event': '6.995KXC',
#    'value': '24:29',
#    'position': ['26', ''],
#    'venue': 'Tonbridge',
#    'meeting': 'ESAA English Schools Championships',
#    'date': '19 Mar 22'},
#   {'event': '7.2KXC',
#    'value': '24:14',
#    'position': ['5', ''],
#    'venue': 'Reigate',
#    'meeting': "South East Schools' Inter Counties",
#    'date': '5 Feb 22'},
#   {'event': '9.1KXC',
#    'value': '34:01',
#    'position': ['30', ''],
#    'venue': 'Aldershot',
#    'meeting': 'Hampshire League',
#    'date': '12 Nov 22'},
#   {'event': '10KXC',
#    'value': '36:44',
#    'position': ['58', ''],
#    'venue': 'Parliament Hill',
#    'meeting': 'ECCA Saucony English National Championships',
#    'date': '26 Feb 22'},
#   {'event': '1500',
#    'value': '4:21.29',
#    'position': ['11', '1'],
#    'venue': 'Worthing',
#    'meeting': 'Worthing Open Meeting',
#    'date': '2 May 21'},
#   {'event': '1500',
#    'value': '4:23.8',
#    'position': ['9', 'B'],
#    'venue': 'Aldershot',
#    'meeting': 'Aldershot, Farnham & District Open Meeting',
#    'date': '8 May 21'},
#   {'event': '1500',
#    'value': '4:25.48',
#    'position': ['11', '11'],
#    'venue': 'Harrow',
#    'meeting': 'Harrow AC Spring Open',
#    'date': '29 Apr 21'},
#   {'event': '3000',
#    'value': '9:06.96',
#    'position': ['1', 'A'],
#    'venue': 'Bracknell',
#    'meeting': 'Southern Athletics League - Mid West',
#    'date': '11 Jul 21'},
#   {'event': '3000',
#    'value': '9:13.50',
#    'position': ['1', 'B'],
#    'venue': 'Eton',
#    'meeting': 'Youth Development League Upper Southern North West',
#    'date': '25 Jul 21'},
#   {'event': '3000',
#    'value': '9:13.61',
#    'position': ['1', 'A'],
#    'venue': 'Milton Keynes',
#    'meeting': 'BMC PB Classic',
#    'date': '5 Jun 21'},
#   {'event': '3000',
#    'value': '9:17.47',
#    'position': ['3', '2'],
#    'venue': 'Bromley',
#    'meeting': 'London Hurdles & Middle Distance Open Meeting',
#    'date': '22 May 21'},
#   {'event': '3000',
#    'value': '9:26.91',
#    'position': ['10', '1'],
#    'venue': 'Worthing',
#    'meeting': 'The Opener',
#    'date': '18 Apr 21'},
#   {'event': '5000',
#    'value': '15:54.09',
#    'position': ['5', ''],
#    'venue': 'Bedford',
#    'meeting': 'South of England U20/Senior Championships',
#    'date': '12 Jun 21'},
#   {'event': '5000',
#    'value': '16:10.7',
#    'position': ['1', 'ns'],
#    'venue': 'Aldershot',
#    'meeting': 'Southern Athletics League - Mid West',
#    'date': '20 Jun 21'},
#   {'event': '5000',
#    'value': '16:13.2',
#    'position': ['2', 'ns'],
#    'venue': 'Aldershot',
#    'meeting': 'Southern Athletics League - Mid West',
#    'date': '14 Aug 21'},
#   {'event': '3KXCL',
#    'value': '9:28',
#    'position': ['13', 'L3'],
#    'venue': 'Mansfield',
#    'meeting': 'ECCA Saucony English National Relay Championships',
#    'date': '6 Nov 21'},
#   {'event': '3KXCL',
#    'value': '9:40',
#    'position': ['14', 'L1'],
#    'venue': 'Wormwood Scrubs',
#    'meeting': 'South of England AA Relay Championships',
#    'date': '23 Oct 21'},
#   {'event': '5K',
#    'value': '16:03',
#    'position': ['18', '3'],
#    'venue': 'Ardingly',
#    'meeting': 'PB 5K',
#    'date': '5 Apr 21'},
#   {'event': 'parkrun',
#    'value': '16:35',
#    'position': ['2', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 70',
#    'date': '18 Sep 21'},
#   {'event': 'parkrun',
#    'value': '17:03',
#    'position': ['1', ''],
#    'venue': 'Fell Foot',
#    'meeting': 'Fell Foot parkrun # 267',
#    'date': '31 Jul 21'},
#   {'event': 'parkrun',
#    'value': '17:04',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 78',
#    'date': '20 Nov 21'},
#   {'event': 'parkrun',
#    'value': '17:31',
#    'position': ['1', ''],
#    'venue': 'Homewood',
#    'meeting': 'Homewood parkrun # 195',
#    'date': '30 Oct 21'},
#   {'event': '5.053KL',
#    'value': '16:12',
#    'position': ['29', 'L1'],
#    'venue': 'Milton Keynes',
#    'meeting': 'SOAR MK Relays',
#    'date': '26 Sep 21'},
#   {'event': '5.848KL',
#    'value': '19:25',
#    'position': ['35', 'L5'],
#    'venue': 'Sutton Park',
#    'meeting': "ERRA Men's National 6-Stage Relays",
#    'date': '9 Oct 21'},
#   {'event': '5.9KXC',
#    'value': '19:38',
#    'position': ['40', ''],
#    'venue': 'Milton Keynes',
#    'meeting': 'Chiltern League (Inc British Athletics Cross Challenge & Oxford Uni Trials)',
#    'date': '13 Nov 21'},
#   {'event': '8.9KXC',
#    'value': '31:32',
#    'position': ['19', ''],
#    'venue': 'Shotover Hill',
#    'meeting': 'Chiltern League',
#    'date': '16 Oct 21'},
#   {'event': '9.5KXC',
#    'value': '34:46',
#    'position': ['12', ''],
#    'venue': 'Luton',
#    'meeting': 'Chiltern League',
#    'date': '4 Dec 21'},
#   {'event': 'parkrun',
#    'value': '17:56',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 62',
#    'date': '14 Mar 20'},
#   {'event': 'parkrun',
#    'value': '18:04',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 61',
#    'date': '7 Mar 20'},
#   {'event': '1500',
#    'value': '4:26.6',
#    'position': ['6', ''],
#    'venue': 'Hillingdon',
#    'meeting': "Alder Valley Boys' League",
#    'date': '7 Jul 19'},
#   {'event': '1500',
#    'value': '4:36.05',
#    'position': ['7', 'ns'],
#    'venue': 'Reading',
#    'meeting': 'Southern Athletics League Division 1',
#    'date': '15 Jun 19'},
#   {'event': '3000',
#    'value': '9:42.6',
#    'position': ['1', 'ns'],
#    'venue': 'Harrow',
#    'meeting': 'Southern Athletics League Division 1',
#    'date': '13 Jul 19'},
#   {'event': '3000',
#    'value': '10:06.99',
#    'position': ['2', 'ns'],
#    'venue': 'Bromley',
#    'meeting': 'UK Youth Development U17/U20 League Division South Premier',
#    'date': '28 Jul 19'},
#   {'event': 'parkrun',
#    'value': '17:34',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 31',
#    'date': '22 Jun 19'},
#   {'event': 'parkrun',
#    'value': '17:46',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 22',
#    'date': '13 Apr 19'},
#   {'event': 'parkrun',
#    'value': '17:51',
#    'position': ['4', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 23',
#    'date': '20 Apr 19'},
#   {'event': 'parkrun',
#    'value': '17:54',
#    'position': ['2', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 50',
#    'date': '23 Nov 19'},
#   {'event': 'parkrun',
#    'value': '17:59',
#    'position': ['2', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 24',
#    'date': '27 Apr 19'},
#   {'event': 'parkrun',
#    'value': '18:07',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 49',
#    'date': '16 Nov 19'},
#   {'event': 'parkrun',
#    'value': '18:19',
#    'position': ['5', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 10',
#    'date': '19 Jan 19'},
#   {'event': 'parkrun',
#    'value': '18:21',
#    'position': ['4', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 8',
#    'date': '5 Jan 19'},
#   {'event': 'parkrun',
#    'value': '19:13',
#    'position': ['8', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 11',
#    'date': '26 Jan 19'},
#   {'event': '5.5KXC',
#    'value': '19:26',
#    'position': ['10', ''],
#    'venue': 'Luton',
#    'meeting': 'Chiltern League',
#    'date': '7 Dec 19'},
#   {'event': '10K',
#    'value': '36:58',
#    'position': ['50', ''],
#    'venue': 'Walton-on-Thames',
#    'meeting': 'Elmbridge 10K',
#    'date': '21 Jul 19'},
#   {'event': 'parkrun',
#    'value': '18:06',
#    'position': ['1', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 6',
#    'date': '22 Dec 18'},
#   {'event': 'parkrun',
#    'value': '18:26',
#    'position': ['3', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 4',
#    'date': '8 Dec 18'},
#   {'event': 'parkrun',
#    'value': '18:28',
#    'position': ['7', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 7',
#    'date': '29 Dec 18'},
#   {'event': 'parkrun',
#    'value': '18:34',
#    'position': ['3', ''],
#    'venue': 'Brooklands',
#    'meeting': 'Brooklands parkrun # 5',
#    'date': '15 Dec 18'},
#   {'event': 'parkrun',
#    'value': '22:59',
#    'position': ['230', ''],
#    'venue': 'Bushy Park',
#    'meeting': 'Bushy Park parkrun # 586',
#    'date': '22 Aug 15'},
#   {'event': 'parkrun',
#    'value': '26:04',
#    'position': ['461', ''],
#    'venue': 'Bushy Park',
#    'meeting': 'Bushy Park parkrun # 576',
#    'date': '13 Jun 15'}],
#  'rankings': [{'event': '1500',
#    'age group': 'U17',
#    'year': '2019',
#    'rank': '414'},
#   {'event': '1500', 'age group': 'U20', 'year': '2021', 'rank': '359'},
#   {'event': '1500', 'age group': 'U20', 'year': '2022', 'rank': '247'},
#   {'event': '1500', 'age group': 'ALL', 'year': '2022', 'rank': '972'},
#   {'event': '1500', 'age group': 'U20', 'year': '2023', 'rank': '168'},
#   {'event': '1500', 'age group': 'ALL', 'year': '2023', 'rank': '714'},
#   {'event': '1500', 'age group': 'U23', 'year': '2024', 'rank': '118'},
#   {'event': '1500', 'age group': 'ALL', 'year': '2024', 'rank': '417'},
#   {'event': 'Mile', 'age group': 'U20', 'year': '2023', 'rank': '20'},
#   {'event': 'Mile', 'age group': 'ALL', 'year': '2023', 'rank': '146'},
#   {'event': '3000', 'age group': 'U17', 'year': '2019', 'rank': '246'},
#   {'event': '3000', 'age group': 'ALL', 'year': '2019', 'rank': '1601'},
#   {'event': '3000', 'age group': 'U20', 'year': '2021', 'rank': '154'},
#   {'event': '3000', 'age group': 'ALL', 'year': '2021', 'rank': '706'},
#   {'event': '3000', 'age group': 'U20', 'year': '2022', 'rank': '119'},
#   {'event': '3000', 'age group': 'ALL', 'year': '2022', 'rank': '604'},
#   {'event': '3000', 'age group': 'ALL', 'year': '2023', 'rank': '329'},
#   {'event': '3000', 'age group': 'U20', 'year': '2023', 'rank': '55'},
#   {'event': '3000', 'age group': 'ALL', 'year': '2024', 'rank': '146'},
#   {'event': '3000', 'age group': 'U23', 'year': '2024', 'rank': '33'},
#   {'event': '5000', 'age group': 'U20', 'year': '2021', 'rank': '62'},
#   {'event': '5000', 'age group': 'ALL', 'year': '2021', 'rank': '625'},
#   {'event': '5000', 'age group': 'U20', 'year': '2023', 'rank': '29'},
#   {'event': '5000', 'age group': 'ALL', 'year': '2023', 'rank': '271'},
#   {'event': '5000', 'age group': 'ALL', 'year': '2024', 'rank': '136'},
#   {'event': '5000', 'age group': 'U23', 'year': '2024', 'rank': '26'},
#   {'event': '5K', 'age group': 'U17', 'year': '2021', 'rank': '61'},
#   {'event': '5K', 'age group': 'ALL', 'year': '2021', 'rank': '1206'},
#   {'event': '5K', 'age group': 'U20', 'year': '2023', 'rank': '34'},
#   {'event': '5K', 'age group': 'ALL', 'year': '2023', 'rank': '234'},
#   {'event': '5K', 'age group': 'ALL', 'year': '2024', 'rank': '144'},
#   {'event': '5K', 'age group': 'U20', 'year': '2024', 'rank': '14'},
#   {'event': '5K', 'age group': 'U20', 'year': 'AT', 'rank': '72'},
#   {'event': 'parkrun', 'age group': 'U17', 'year': '2019', 'rank': '529'},
#   {'event': 'parkrun', 'age group': 'U15', 'year': '2019', 'rank': '154'},
#   {'event': 'parkrun', 'age group': 'U17', 'year': '2020', 'rank': '184'},
#   {'event': 'parkrun', 'age group': 'U17', 'year': '2021', 'rank': '136'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': '2021', 'rank': '1162'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': '2022', 'rank': '1042'},
#   {'event': 'parkrun', 'age group': 'U20', 'year': '2022', 'rank': '86'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': '2023', 'rank': '683'},
#   {'event': 'parkrun', 'age group': 'U20', 'year': '2023', 'rank': '54'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': '2024', 'rank': '84'},
#   {'event': 'parkrun', 'age group': 'U20', 'year': '2024', 'rank': '5'},
#   {'event': 'parkrun', 'age group': 'U15', 'year': 'AT', 'rank': '1195'},
#   {'event': 'parkrun', 'age group': 'ALL', 'year': 'AT', 'rank': '617'},
#   {'event': 'parkrun', 'age group': 'U17', 'year': 'AT', 'rank': '1525'},
#   {'event': 'parkrun', 'age group': 'U20', 'year': 'AT', 'rank': '76'},
#   {'event': '10K', 'age group': 'U20', 'year': '2024', 'rank': '20'},
#   {'event': '10K', 'age group': 'ALL', 'year': '2024', 'rank': '403'}],
#  'coaching': []}

# %%
from get_pb_data import get_athlete_pb
import pandas as pd

df = pd.DataFrame(get_athlete_pb(1146344))
display(df.T)
# Out:
#            0        1      2      3      4
# event     5K  parkrun     5M    10K     HM
# value  18:05    17:57  29:58  38:15  89:24

# %%
from get_pb_data import get_ids
get_ids(surname='a',club='leigh-on-sea')
# Out:
# ['861652',
#  '796590',
#  '1190417',
#  '328850',
#  '786649',
#  '282454',
#  '882246',
#  '696295',
#  '861917',
#  '801558',
#  '1170526',
#  '801732',
#  '1190423',
#  '801912',
#  '1011652']

# %%
events = {'10K', '5K', 'Mar', 'HM', 'parkrun'}

def get_and_reshape_athlete_data(surname, club):
    # Get the list of athlete IDs
    athlete_ids = get_ids(surname=surname, club=club)
    
    # Initialize an empty list to store athlete data
    all_data = []
    
    # Loop through each athlete ID
    for athlete_id in athlete_ids:
        # Get the personal best data for the athlete
        pb_data = get_athlete_pb(athlete_id)
        
        # Add the athlete ID to each record
        for record in pb_data:
            record['athlete_id'] = athlete_id
            all_data.append(record)
    
    # Create a DataFrame from the list of all data
    df = pd.DataFrame(all_data)
    
    # Pivot the DataFrame to have events as columns
    pivot_df = df.pivot(index='athlete_id', columns='event', values='value')
    
    # Reset the index to turn the index into a column
    pivot_df.reset_index(inplace=True)
    
    # Filter the DataFrame to include only the specified events
    pivot_df = pivot_df[['athlete_id'] + list(events)]
    
    return pivot_df

# Example usage
surname = 'a'
club = 'leigh-on-sea'
reshaped_df = get_and_reshape_athlete_data(surname, club)

print(reshaped_df)
# Out:
# event athlete_id       HM     5K    10K      Mar parkrun
# 0        1011652  2:04:45    NaN    NaN      NaN   28:15
# 1        1170526  1:58:32    NaN  48:21  4:42:46   22:20
# 2        1190417  2:19:30    NaN    NaN      NaN   25:45
# 3        1190423  2:07:42    NaN    NaN      NaN     NaN
# 4         282454  1:58:18  26:18  52:44  5:19:18     NaN
# 5         328850  1:50:28  28:31  48:50  4:35:44   23:14
# 6         696295      NaN    NaN  59:06      NaN   25:29
# 7         786649    94:32    NaN  41:57  3:35:31   20:00
# 8         796590      NaN    NaN    NaN  4:53:57     NaN
# 9         801558  2:38:47    NaN    NaN      NaN   31:03
# 10        801732      NaN    NaN    NaN      NaN   32:18
# 11        801912    99:32  21:20  46:47  4:46:24   20:28
# 12        861652      NaN    NaN  79:04      NaN   33:19
# 13        861917      NaN    NaN  48:45  3:55:38   22:42
# 14        882246  2:16:03    NaN  67:29      NaN     NaN

# %%
def get_all_athlete_data(club):
    # Initialize an empty DataFrame to store all athlete data
    all_athlete_data = pd.DataFrame()
    #  defghijklmnopqrstuvwxyz
    # Loop through each letter in the alphabet
    for char in 'abc':
        # Get the reshaped athlete data for the current letter
        reshaped_df = get_and_reshape_athlete_data(surname=char, club=club)
        
        # Append the current DataFrame to the all_athlete_data DataFrame
        all_athlete_data = pd.concat([all_athlete_data, reshaped_df], ignore_index=True)
    
    return all_athlete_data

club = 'leigh-on-sea'
all_data_df = get_all_athlete_data(club)
print(all_data_df)
# Out:
# event athlete_id       HM     5K    10K      Mar parkrun
# 0        1011652  2:04:45    NaN    NaN      NaN   28:15
# 1        1170526  1:58:32    NaN  48:21  4:42:46   22:20
# 2        1190417  2:19:30    NaN    NaN      NaN   25:45
# 3        1190423  2:07:42    NaN    NaN      NaN     NaN
# 4         282454  1:58:18  26:18  52:44  5:19:18     NaN
# ..           ...      ...    ...    ...      ...     ...
# 122       804761  1:59:45    NaN  53:24      NaN   25:12
# 123       864965      NaN    NaN  62:52      NaN     NaN
# 124       980889    85:18    NaN  37:53      NaN   18:02
# 125       998314  2:25:44    NaN    NaN      NaN     NaN
# 126       998324      NaN    NaN    NaN      NaN   28:43
#
# [127 rows x 6 columns]
